# %% [markdown]
# # COMPSCI 690V - hw1 - Interactive Bokeh Visualizations

# %% [markdown]
# ### Read in three datasets from the Gapminder website.

# %%
import pandas as pd

gdp_df = pd.read_excel('indicator gapminder gdp_per_capita_ppp.xlsx', index_col=0)
traffic_df = pd.read_excel('RTI age adjusted indicator LIVE.xlsx', index_col=0)
pop_growth_df = pd.read_excel('population growth.xlsx', index_col=0)

# Find the intersection of countries among the three datasets.
countries = list(set(gdp_df.index).intersection(traffic_df.index, pop_growth_df.index))

# %% [markdown]
# ### Import standard functions.

# %%
from bokeh.io import output_notebook, push_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, BoxSelectTool, BoxZoomTool, LassoSelectTool
from bokeh.models import NumeralTickFormatter
from ipywidgets import interact

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d6e21482-6a4b-4ebb-be6d-f1f777d2bc44">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Plot the data using bokeh library.

# %%
source = ColumnDataSource(
        data = dict(
            x = gdp_df[2003].loc[countries],
            y = traffic_df[2003].loc[countries],
            p = pop_growth_df["2003"].loc[countries],
            c = countries,
            size = (pop_growth_df["2003"].loc[countries] - min(pop_growth_df["2003"].loc[countries]))*10
        )
    )

hover = HoverTool(
        tooltips=[
            ("Country", "@c"),
            ("GDP", "@x{$ 0,0}"),
            ("Traffic mortality", "@y{0.0}"),
            ("Population growth", "@p{0.00}")
        ]
    )

TOOLS = "pan, box_select,box_zoom,lasso_select,reset, crosshair"
fig = figure(tools=TOOLS, title="Scatter Plot")
fig.add_tools(hover)
fig.xaxis.axis_label = 'GDP per capita'
fig.yaxis.axis_label = 'Traffic mortality per 100,000, age adjusted'
fig.circle('x', 'y', source=source, size='size', fill_alpha=0.5, hover_fill_color="firebrick")
fig.xaxis[0].formatter = NumeralTickFormatter(format="$0,0")
fig.yaxis[0].formatter = NumeralTickFormatter(format="0")

def update(year):
    year_str = str(year)
    new_data = dict(
        x = gdp_df[year].loc[countries],
        y = traffic_df[year].loc[countries],
        p = pop_growth_df[year_str].loc[countries],
        c = countries,
        size = (pop_growth_df[year_str].loc[countries] - min(pop_growth_df[year_str].loc[countries]))*10
    )
    source.data = new_data
    fig.title.text = str(year)
    push_notebook()

show(fig, notebook_handle=True)
interact(update, year=(1995, 2004, 1));
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b6e35663-6867-41d4-b397-aadc493c5841"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b6e35663-6867-41d4-b397-aadc493c5841");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("9b81977c-4c18-426f-9ddb-3f45040beaef", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b6e35663-6867-41d4-b397-aadc493c5841");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b6e35663-6867-41d4-b397-aadc493c5841' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"23d74129-6115-4792-b201-48567e9cdbe0":{"roots":{"references":[{"attributes":{"below":[{"id":"b38c96c7-4a1a-44a1-9380-8f8ca37ffe6b","type":"LinearAxis"}],"left":[{"id":"9294d39c-1723-4cb4-9a72-8b0fdc6b8e38","type":"LinearAxis"}],"renderers":[{"id":"b38c96c7-4a1a-44a1-9380-8f8ca37ffe6b","type":"LinearAxis"},{"id":"221d049b-eec7-4e89-9f77-85d2939002df","type":"Grid"},{"id":"9294d39c-1723-4cb4-9a72-8b0fdc6b8e38","type":"LinearAxis"},{"id":"22777ddf-17b7-4b35-b62b-d3c0e95b95ee","type":"Grid"},{"id":"e76b00f0-99ef-48dd-8ad0-c5ee8649d79e","type":"BoxAnnotation"},{"id":"97573197-3205-4f3d-b513-3eab40c56594","type":"BoxAnnotation"},{"id":"17adfcb3-3b6b-40b7-b184-f034f767ca15","type":"PolyAnnotation"},{"id":"09fc6f1e-3eba-44f7-b3e0-35fff70ed467","type":"GlyphRenderer"}],"title":{"id":"6da6096b-d6ac-4c17-a19e-94e010cd874b","type":"Title"},"tool_events":{"id":"0e2be508-f1da-4e95-b831-36e4834306af","type":"ToolEvents"},"toolbar":{"id":"241d7776-dd07-4285-a245-6a1d19c2a584","type":"Toolbar"},"x_range":{"id":"25ec5d95-bade-40c6-b4a7-b75ca065100c","type":"DataRange1d"},"y_range":{"id":"26647c48-0ff2-4598-a6c0-40f8a584be4a","type":"DataRange1d"}},"id":"ea1a9bcc-865d-4ae4-b651-87c208ee1381","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Scatter Plot"},"id":"6da6096b-d6ac-4c17-a19e-94e010cd874b","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"ea1a9bcc-865d-4ae4-b651-87c208ee1381","subtype":"Figure","type":"Plot"},"tooltips":[["Country","@c"],["GDP","@x{$ 0,0}"],["Traffic mortality","@y{0.0}"],["Population growth","@p{0.00}"]]},"id":"78ed352c-0247-40e3-bd40-9fb4bece4395","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"70af68b0-ba27-45fd-8ae5-27faebebfe06","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e59d0eae-8176-4a68-ba8a-648a61b04122","type":"PanTool"},{"id":"a34e27c5-e0b0-4731-861a-d4f3bd13a5ae","type":"BoxSelectTool"},{"id":"54643553-f02b-4f8a-9373-4ba4865f2968","type":"BoxZoomTool"},{"id":"280ec6fb-85b1-472c-b057-7ed20a9993eb","type":"LassoSelectTool"},{"id":"8908ef09-0e93-496f-b59a-2a92e63377c4","type":"ResetTool"},{"id":"2d045caa-9ce8-4f69-ba7d-2d17e10c3cfb","type":"CrosshairTool"},{"id":"78ed352c-0247-40e3-bd40-9fb4bece4395","type":"HoverTool"}]},"id":"241d7776-dd07-4285-a245-6a1d19c2a584","type":"Toolbar"},{"attributes":{"fill_color":{"value":"firebrick"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"065be82a-71c5-44fe-9fab-f55834ebe02f","type":"Circle"},{"attributes":{"callback":null},"id":"25ec5d95-bade-40c6-b4a7-b75ca065100c","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"97573197-3205-4f3d-b513-3eab40c56594","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ae630e5-7039-4af8-98d8-66d12990a7c4","type":"Circle"},{"attributes":{"axis_label":"GDP per capita","formatter":{"id":"3d48b7f4-4784-4728-91fc-132f21c4d598","type":"NumeralTickFormatter"},"plot":{"id":"ea1a9bcc-865d-4ae4-b651-87c208ee1381","subtype":"Figure","type":"Plot"},"ticker":{"id":"f0b84495-e243-47f4-814c-2b4340bf9aa0","type":"BasicTicker"}},"id":"b38c96c7-4a1a-44a1-9380-8f8ca37ffe6b","type":"LinearAxis"},{"attributes":{"callback":null},"id":"26647c48-0ff2-4598-a6c0-40f8a584be4a","type":"DataRange1d"},{"attributes":{},"id":"f0b844 ...
