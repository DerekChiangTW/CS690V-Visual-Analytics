# %% [markdown]
# # COMPSCI 690V - hw1 - Interactive Bokeh Visualizations

# %% [markdown]
# ### Read in three datasets from the Gapminder website.

# %%
import pandas as pd

gdp_df = pd.read_excel('data/Gapminder/indicator gapminder gdp_per_capita_ppp.xlsx', index_col=0)
traffic_df = pd.read_excel('data/Gapminder/RTI age adjusted indicator LIVE.xlsx', index_col=0)
pop_growth_df = pd.read_excel('data/Gapminder/population growth.xlsx', index_col=0)


# Make the column names ints not strings for handling.
columns = list(pop_growth_df.columns)
years_to_int = list(range(int(pop_growth_df.columns[0]), int(pop_growth_df.columns[-1])+1))
rename_dict = dict(zip(columns, years_to_int))
pop_growth_df = pop_growth_df.rename(columns=rename_dict)


# Find the intersection of countries and years among the three datasets.
countries = list(set(gdp_df.index).intersection(traffic_df.index, pop_growth_df.index))
years = list(set(gdp_df.columns).intersection(traffic_df.columns, pop_growth_df.columns))


# Get the clean data.
gdp_df = gdp_df[years].loc[countries]
traffic_df = traffic_df[years].loc[countries]
pop_growth_df = pop_growth_df[years].loc[countries]


data={}
panel = pd.Panel({'gdp': gdp_df, 'traffic': traffic_df, 'pop': pop_growth_df})
for year in years:
    df = panel[:,:,year]
    df['countries'] = countries
    data[year] = df.to_dict('series')

# %% [markdown]
# ### Import standard functions.

# %%
from bokeh.io import output_notebook, push_notebook, show
from bokeh.plotting import figure
from bokeh.models import (
    ColumnDataSource, SingleIntervalTicker, CustomJS, Slider,
    TapTool, HoverTool, BoxSelectTool, BoxZoomTool, LassoSelectTool
)
from bokeh.models import NumeralTickFormatter
from ipywidgets import interact
from bokeh.layouts import column, row, gridplot

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aca07e2f-3554-45b4-a38d-0ced72876087">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Plot the data using bokeh library.

# %%
year = years[-3]

s1 = ColumnDataSource(data=data[year])
s2 = ColumnDataSource(data=dict(x=[], y=[]))
s3 = ColumnDataSource(data=dict(x=[], y=[]))
gdp_source = ColumnDataSource(gdp_df.transpose())

TOOLS_left = "pan,box_select,box_zoom,lasso_select,reset"
TOOLS_right = "pan,box_select,box_zoom,reset"

left = figure(
    plot_width=500,
    plot_height=500,
    tools=TOOLS_left,
    title="Scatter Plot",
    toolbar_location="above"
)

left.xaxis.ticker = SingleIntervalTicker(interval=20000)
left.yaxis.ticker = SingleIntervalTicker(interval=5)
left.xaxis[0].formatter = NumeralTickFormatter(format="$0,0")
left.yaxis[0].formatter = NumeralTickFormatter(format="0")
left.xaxis.axis_label = 'GDP per capita'
left.yaxis.axis_label = 'Traffic mortality per 100,000, age adjusted'

left.circle(
    'gdp',
    'traffic',
    source=s1,
    size=20,
    fill_alpha=0.4,
    line_alpha=0.4,
    fill_color='olive',
    line_color='olive',
    
    hover_fill_color="firebrick",
    hover_line_color="firebrick",
    hover_fill_alpha=0.8,
    
    # set visual properties for selected glyphs
    selection_color="firebrick",
    selection_line_color="firebrick",
    selection_fill_alpha=0.8,
)

right_up = figure(
    plot_width=450,
    plot_height=250,
    tools=TOOLS_right,
    title="GDP Time Series",
    toolbar_location="above"
)
right_up.line('x', 'y', source=s2, alpha=0.6)

right_down = figure(
    plot_width=450,
    plot_height=250,
    tools=TOOLS_right,
    title="Traffic Mortality Time Series",
    toolbar_location="above"
)
right_down.line('x', 'y', source=s2, alpha=0.6)

hover = HoverTool(
        tooltips=[
            ("Country", "@countries"),
            ("GDP", "@gdp{$ 0,0}"),
            ("Traffic mortality", "@traffic{0.0}"),
            ("Population growth", "@pop{0.00}")
        ]
    )

tap = TapTool(callback=CustomJS(args=dict(s1=s1), code="""
    var selected= cb_obj.selected['1d'].indices;
    var data = cb_obj.data;
    var country = data['countries'][selected];
    alert(country);
    """))

left.add_tools(hover)
left.add_tools(tap)

def update(year):
    new_data = data[year]
    s1.data = new_data
    left.title.text = str(year)
    push_notebook()


plot= row(left, column(right_up, right_down))

show(plot, notebook_handle=True);
interact(update, year=(years[0], years[-1], 1));
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1b932547-f1ef-4e93-92ba-45b849f6d78f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("1b932547-f1ef-4e93-92ba-45b849f6d78f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b932547-f1ef-4e93-92ba-45b849f6d78f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b932547-f1ef-4e93-92ba-45b849f6d78f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f52b7f18-e138-490f-9e72-e73da32cded4":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["gdp","pop","traffic","countries"],"data":{"countries":["Bosnia and Herzegovina","Gabon","Nauru","Bhutan","Antigua and Barbuda","Oman","Yugoslavia","Japan","Central African Republic","Swaziland","Chile","Bahamas","Austria","Seychelles","Burundi","Eritrea","Moldova","Lithuania","Czech Republic","Serbia and Montenegro","St. Kitts and Nevis","Sierra Leone","Iran","Niue","St. Vincent and the Grenadines","Ecuador","Cape Verde","Dominican Republic","Germany","Suriname","Uzbekistan","Mauritius","Trinidad and Tobago","Italy","Macedonia, FYR","Madagascar","Nicaragua","Iraq","Argentina","Colombia","Azerbaijan","Turkmenistan","Sudan","Turkey","Ghana","United States","Zambia","Jamaica","North Korea","Portugal","Solomon Islands","Guinea-Bissau","Vanuatu","Congo, Dem. Rep.","Micronesia, Fed. Sts.","Burkina Faso","Ireland","USSR","Denmark","Ethiopia","Rwanda","Equatorial Guinea","Chad","United Arab Emirates","Uruguay","Afghanistan","Gambia","Djibouti","Kiribati","Malta","Timor-Leste","Marshall Islands","Norway","Tanzania","Guinea","New Zealand","Sao Tome and Principe","Netherlands","Finland","Indonesia","Maldives","Nepal","Togo","West Germany","Qatar","Cuba","Belize","Palau","Egypt","Guatemala","Cyprus","Jordan","Luxembourg","Pakistan","Saudi Arabia","Spain","France","Tuvalu","Samoa","Montenegro","Cook Is","Iceland","Kenya","Barbados","Bolivia","Ukraine","Switzerland","Papua New Guinea","Israel","Mexico","Lebanon","Serbia","Slovak Republic","Mauritania","Morocco","Thailand","Nigeria","Myanmar","Costa Rica","Comoros","Peru","Kazakhstan","Haiti","Botswana","Hungary","Andorra","Mali","Sweden","Kuwait","Congo, Rep.","Mongolia","Namibia","Albania","Malawi","Greece","Bahrain","Mozambique","Sri Lanka","Australia","Zimbabwe","Niger","Puerto Rico","Senegal","Belgium","Monaco","Armenia","Malaysia","Lesotho","Belarus","Cote d'Ivoire","Benin","Fiji","India","Paraguay","Lao","Brazil","Angola","Canada","Czechoslovakia","San Marino","Guyana","Latvia","St. Lucia","Uganda","Grenada","British Virgin Islands","Georgia","Croatia","Tajikistan","Tunisia","Vietnam","China","Singapore","Bangladesh","Tonga","Romania","Estonia","Honduras","El Salvador","Libya","Dominica","Cameroon","Russia","South Africa","Syria","Yemen","Liberia","Poland","East Germany","Slovenia","Panama","Brunei","Bulgaria","Cambodia","Algeria","Venezuela","United Kingdom","Philippines","Somalia"],"gdp":{"__ndarray__":"...","dtype":"float64","shape":[199]},"pop":{"__ndarray__":"...","dtype":"float64","shape":[199]},"traffic":{"__ndarray__":"...","dtype":"float64","shape":[199]}}},"id":"5ef8f2cf-13c4-4676-9393-ef5ca5b1b06e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[],"y":[]}},"id":"01040ae8-7fdc-47bc-aced-7bbb1d91569e","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"ca018d6c-fb41-4338-9240-335c08c01e0b","type":"LinearAxis"}],"left":[{"id":"b9f45c96-c362-48db-b854-345dd6b0f0ec","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"ca018d6c-fb41-4338-9240-335c08c01e0b","type":"LinearAxis"},{"id":"51855cee-cac6-4082-bb01-00f253b13a30","type":"Grid"},{"id":"b9f45c96-c362-48db-b854-345dd6b0f0ec","type":"LinearAxis"},{"id":"b6219092-1e8d-46be-b235-4fe5b480c756","type":"Grid"},{"id":"45c050d4-94f1-4eb4-bfba-f3bb79b2529f","type":"BoxAnnotation"},{"id":"42c40264-84ed-4c5f-a9f3-b1bfa037ba08","type":"BoxAnnotation"},{"id":"c5c29f79-4bdc-41cd-b9cf-11f9d71fd29d","type":"PolyAnnotation"},{"id":"95ff2acb-517d-4fef-a41d-62a0027320c0","type":"GlyphRenderer"}],"title":{"id":"5069d577-55b9-4516-9bb4-b5a6d7551ef3","type":"Title"},"toolbar":{"id":"0c9455d4-cc11-49e6-9be0-40bb875ca4ca","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"15e81a2a-f5a4-48e9-b850-f97eafb879b6","type":"DataRange1d"},"x_scale":{"id":"546a7622-4963-4d23-8c36-f2d9f43a44a8","type":"LinearScale"},"y_range":{"id":" ...
